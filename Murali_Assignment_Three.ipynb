# %% [markdown]
# <a href="https://colab.research.google.com/github/muraliRoyal1/venkatasiva_INFO5731_Fall2020/blob/master/Murali_Assignment_Three.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment Three**
#
# In this assignment, you are required to conduct information extraction, semantic analysis based on **the dataset you collected from assignment two**. You may use scipy and numpy package in this assignment.

# %% [markdown]
# # **Question 1: Understand N-gram**

# %% [markdown]
# (45 points). Write a python program to conduct N-gram analysis based on the dataset in your assignment two:
#
# (1) Count the frequency of all the N-grams (N=3).
#
# (2) Calculate the probabilities for all the bigrams in the dataset by using the fomular count(w2 w1) / count(w2). For example, count(really like) / count(really) = 1 / 3 = 0.33.
#
# (3) Extract all the **noun phrases** and calculate the relative probabilities of each review in terms of other reviews (abstracts, or tweets) by using the fomular frequency (noun phrase) / max frequency (noun phrase) on the whole dataset. Print out the result in a table with column name the all the noun phrases and row name as all the 100 reviews (abstracts, or tweets).

# %%
# Write your code here
import requests
import csv
from bs4 import BeautifulSoup
Q1=[i*10 for i in range(1,11)]
Q2=[]
for i in l1:
  URL = 'https://citeseerx.ist.psu.edu/search?q=natural+language+processing&t=doc&sort=rlv&start={}'.format(i)
  page = requests.get(URL)
  soup = BeautifulSoup(page.content, 'html.parser')
  for i in soup.find_all("div",{"class":"snippet"}):
    Q2.append(i.text)
import pandas as pd
df=pd.DataFrame({"Abstract":Q2})
df.to_csv("my_cse.csv")
df
# Out:
#                                              Abstract
# 0   "... Introduction  Statistical natural languag...
# 1   "... The paper summarizes the essential proper...
# 2   "... ABSTRACT: Language is way of communicatin...
# 3   "... We report experiments on the use of stand...
# 4   "... this paper, we will describe a simple rul...
# ..                                                ...
# 95                      "...   9. Bibliography   ..."
# 96  "... Applying Natural Language Processing tech...
# 97  "... Examples of natural languages are Chinese...
# 98  "... A number of powerful modelling techniques...
# 99  "... A semi-automated approach for the design ...
#
# [100 rows x 1 columns]

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from textblob import Word
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
import pandas as pd
import nltk
import re
import string

df = pd.read_csv("my_cse.csv")

#Removing special characters
df["cln_abstract"] = df["Abstract"].str.replace(r"[^a-zA-Z ]+", " ").str.strip()

#Punctuation removal
df['cln_abstract'] = df['cln_abstract'].str.replace('[^\w\s]','')

#remove numbers
df['cln_abstract'] = df['cln_abstract'].str.rstrip(string.digits)

#Stopwords removal
stop = stopwords.words('english')
df['cln_abstract'] = df['cln_abstract'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

#Lower casing
df['cln_abstract'] = df['cln_abstract'].apply(lambda x: " ".join(x.lower() for x in x.split()))


#Stemming
from nltk.stem import PorterStemmer
st = PorterStemmer()
df['cln_abstract'][:5].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))


#Lemmatization
df['cln_abstract'] = df['cln_abstract'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('universal_tagset')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# True

# %%
pos_tag=[]
frequency=[]
j=0
for i in df['cln_abstract']:
  token=nltk.word_tokenize(i)
  pos_tag.append(nltk.pos_tag(token,tagset='universal'))
  frequency.append(nltk.FreqDist(tag for (word, tag) in pos_tag[0]))
  print(pos_tag[j])
  print(frequency[j])
  j=j+1
print(frequency)
# Out:
# [('introduction', 'NOUN'), ('statistical', 'ADJ'), ('natural', 'ADJ'), ('language', 'NOUN'), ('processing', 'NOUN'), ('snlp', 'ADJ'), ('field', 'NOUN'), ('lying', 'VERB'), ('intersection', 'ADJ'), ('natural', 'ADJ'), ('language', 'NOUN'), ('processing', 'NOUN'), ('machine', 'NOUN'), ('learning', 'VERB'), ('snlp', 'ADJ'), ('di', 'NOUN'), ('er', 'VERB'), ('traditional', 'ADJ'), ('natural', 'ADJ'), ('language', 'NOUN'), ('processing', 'NOUN'), ('instead', 'ADV'), ('linguist', 'ADJ'), ('manually', 'ADV'), ('construct', 'VERB'), ('model', 'NOUN'), ('given', 'VERB'), ('linguistic', 'ADJ')]
# <FreqDist with 4 samples and 28 outcomes>
# ...

# %%
# !pip install benepar
# Out:
# ...
#      |████████████████████████████████| 81kB 2.3MB/s
# ...
#   Created wheel for benepar: filename=benepar-0.1.2-cp36-cp36m-linux_x86_64.whl size=104463 sha256=5727b993f50b1882a7167db84e3f60fd6e41f86ca9629cb76f486ef155b6bae2
#   Stored in directory: /root/.cache/pip/wheels/c6/f5/06/d88543b19a9b326007d7538298a139e994b1d2eecb003bf5af
# Successfully built benepar
# ...

# %%
# %tensorflow_version 1.x
import spacy
import benepar
from benepar.spacy_plugin import BeneparComponent
benepar.download('benepar_en')
# Out:
# TensorFlow 1.x selected.
# [nltk_data] Downloading package benepar_en to /root/nltk_data...
# True

# %%
import spacy
nlp=spacy.load('en_core_web_sm')
from spacy import displacy
for i in df['cln_abstract']:
  displacy.render(nlp(i),jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="41af3b1113444bcd9c61cdacaf9b3b9c-0" class="displacy" width="4950" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">introduction</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">statistical</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
# ...

# %%
# Recognition Named Entity 
import spacy
from spacy import displacy
ner_dict=[]
nlp = spacy.load('en_core_web_sm')
for i in df['cln_abstract']:
  for entity in nlp(i).ents:
    ner_dict.append((entity.label_,entity.text))
    print(entity.label_,entity.text)
# Out:
# ORG the paper summarizes essential property document retrieval review conventional practice research finding
# ORG nlp
# PERSON leake owen
# ORG nlp
# ORG nlp
# ORG nlp
# ORG nlp
# ORG nlp
# CARDINAL one
# ORG nlp
# LANGUAGE english
# ORG nlp
# PERSON automaton
# PERSON automaton
# ORG nlp
# ORG nlp
# ORG nlp
# DATE four decade
# ORG digital
# ORG algorithm
# DATE recent year
# ORG nlp
# ORG nlp
# DATE past year
# PERSON query
# PERSON questionanswering qa technical
# PERSON qa web
# ORG qa
# PERSON universit quot de saarlandes
# ORG uni
# GPE hamburg
# ORG sri
# DATE last five year
# CARDINAL two
# DATE early day
# ORG nlp
# DATE last year
# GPE pa
# ORG nlp
# CARDINAL two
# CARDINAL two
# ORG nlp
# ORG algorithm
# CARDINAL two
# ORG algorithm
# CARDINAL two
# ORG nlp
# ORG nlp
# CARDINAL three
# ORG nlp
# CARDINAL two
# ORDINAL first
# DATE last thirtyfive year
# CARDINAL one three
# ORG nlp
# ORG nlp
# ORG nlp
# ORG nlp
# ORDINAL first
# ORDINAL second
# ORG nlp
# NORP indian
# ...

# %%
data=df.head(100)
data
# Out:
#     Unnamed: 0  ...                                       Abstract_cln
# 0            0  ...  introduction statistical natural language proc...
# 1            1  ...  the paper summarizes essential property docume...
# 2            2  ...  abstract language way communicating word langu...
# 3            3  ...  we report experiment use standard natural lang...
# 4            4  ...  paper describe simple rule based approach auto...
# ..         ...  ...                                                ...
# 95          95  ...                                       bibliography
# 96          96  ...  applying natural language processing technique...
# 97          97  ...  example natural language chinese english itali...
# 98          98  ...  a number powerful modelling technique develope...
# 99          99  ...  a semi automated approach design database enha...
#
# [100 rows x 3 columns]

# %%
data.to_csv('cleaned_data.csv')

# %%
import nltk
from nltk.util import ngrams

# %%
#Create all frequncies of unigrams, bigrams, trigrams for future use in the assignment
cleaned_data = open('cleaned_data.csv', "r")
unigrams = ngrams(cleaned_data.read().split(), 1)
unigra_freq_dist=nltk.FreqDist(unigrams)

# %%
#creating bigram for future use in the assignment
cleaned_data = open('cleaned_data.csv', "r")
bigrams = ngrams(cleaned_data.read().split(), 2)
bigra_freq_dist=nltk.FreqDist(bigrams)

# %%
clean_data = open('cleaned_data.csv', "r")
trigrams = ngrams(cleaned_data.read().split(), 3)
trigra_freq_dist=nltk.FreqDist(trigrams)
trigra_freq_dist
# Out:
# FreqDist()

# %%
#1.2 : This is a fucntion which will give probability of  all the bigrams in the dataset from formula
def probability_bigram():
  for bigram_values in bigra_freq_dist:
#    print(bigram_values)
    print(("bigram values", bigram_values,"Probability :",bigra_freq_dist[bigram_values]/unigra_freq_dist[(bigram_values[0],)]))

probability_bigram()
# Out:
# ('bigram values', (',Unnamed:', '0,Abstract,Abstract_cln'), 'Probability :', 1.0)
# ('bigram values', ('0,Abstract,Abstract_cln', '0,0,"""...'), 'Probability :', 1.0)
# ('bigram values', ('0,0,"""...', 'Introduction'), 'Probability :', 1.0)
# ('bigram values', ('Introduction', 'Statistical'), 'Probability :', 0.2)
# ('bigram values', ('Statistical', 'natural'), 'Probability :', 1.0)
# ('bigram values', ('natural', 'language'), 'Probability :', 0.9051724137931034)
# ('bigram values', ('language', 'processing'), 'Probability :', 0.6)
# ('bigram values', ('processing', '(SNLP)'), 'Probability :', 0.010101010101010102)
# ('bigram values', ('(SNLP)', 'is'), 'Probability :', 1.0)
# ('bigram values', ('is', 'a'), 'Probability :', 0.15517241379310345)
# ('bigram values', ('a', 'field'), 'Probability :', 0.00980392156862745)
# ('bigram values', ('field', 'lying'), 'Probability :', 0.18181818181818182)
# ('bigram values', ('lying', 'in'), 'Probability :', 0.5)
# ...

# %%
#1.3:
import nltk
nltk.download('averaged_perceptron_tagger')
from textblob import TextBlob
cleaned_data = open('cleaned_data.csv', "r")

_noun = lambda pos: pos[:2] == 'NN'
tokenized = nltk.word_tokenize(cleaned_data.read())
nouns = [word for (word, pos) in nltk.pos_tag(tokenized) if _noun(pos)] 
#displays all the nouns in the clean data
print(nouns)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# ...

# %%
#or other way
import nltk
nltk.download('brown')
cleaned_data = open('cleaned_data.csv', "r")
#print(clean_data)
blob = TextBlob(cleaned_data.read())
noun_phrases = blob.noun_phrases
print(noun_phrases) #to print all the noun phrases from the clean dataset
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# ...

# %%
df_noun = pd.DataFrame(noun_phrases, columns = ['noun_phrases'])
df_noun # adding the noun phrases to the data frame
# Out:
#                                            noun_phrases
# 0                                               unnamed
# 1                                              abstract
# 2                                          abstract_cln
# 3                              introduction statistical
# 4                           natural language processing
# ...                                                 ...
# 1111                                         approa ...
# 1112                           approach design database
# 1113                                       erd notation
# 1114  stage database development stage user requirem...
# 1115           requirement determination stage analysis
#
# [1116 rows x 1 columns]

# %%
import nltk

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
clean_data = open('cleaned_data.csv', "r")
f = nltk.FreqDist(noun_phrases)
f # gives the frequncy of noun phrases
# Out:
# FreqDist({'# programs': 1,
#           '... ...': 6,
#           '... algorithms': 1,
#           '... research': 1,
#           '... uni-hamburg.de ...': 1,
#           '... visual development environment': 1,
#           '... work': 1,
#           'ability search': 1,
#           'abstract': 12,
#           'abstract diff software program detects difference': 1,
#           'abstract language way': 1,
#           'abstract metabolism machinery life signal transduction': 1,
#           'abstract-': 1,
#           'abstract-a': 1,
#           'abstract_cln': 1,
#           'abstract—natural': 1,
#           'abstract—natural language processing': 1,
#           'account meaning extraction pr': 1,
#           'acquaintance principle': 1,
#           'acquisition process': 1,
#           'acquisition process ...': 1,
#           'adaptive model': 1,
#           'adaptive models': 1,
#           'aid biologist': 1,
#           'aid machine translation speech recognition w': 1,
# ...

# %% [markdown]
# # **Question 2: Undersand TF-IDF and Document representation**

# %% [markdown]
# (40 points). Starting from the documents (all the reviews, or abstracts, or tweets) collected for assignment two, write a python program:
#
# (1) To build the **documents-terms weights (tf*idf) matrix bold text**.
#
# (2) To rank the documents with respect to query (design a query by yourself, for example, "An Outstanding movie with a haunting performance and best character development") by using **cosine similarity**.

# %%
# Write your code here
tf_result = (df['cln_abstract']).apply(lambda x: pd.value_counts(x.split(" "))).sum(axis = 0).reset_index()
tf_result.columns = ['cln_abstract','tf']
tf_result
# Out:
#        Abstract_cln    tf
# 0        processing  62.0
# 1           natural  74.0
# 2          language  89.0
# 3              snlp   2.0
# 4          linguist   2.0
# ...             ...   ...
# 1024  determination   1.0
# 1025       enhanced   1.0
# 1026       supposed   1.0
# 1027       notation   1.0
# 1028         approa   1.0
#
# [1029 rows x 2 columns]

# %%
import numpy as np
#calculating tf*idf
for i,j in enumerate(tf_result['cln_abstract']):
  tf_result.loc[i, 'idf'] = np.log(df.shape[0]/(len(df[df['cln_abstract'].str.contains(j)])))
tf_result['tf*idf'] = tf_result['tf'] * tf_result['idf']
tf_result
# Out:
#        Abstract_cln    tf       idf     tf*idf
# 0        processing  62.0  0.634878  39.362453
# 1           natural  74.0  0.494296  36.577928
# 2          language  89.0  0.494296  43.992373
# 3              snlp   2.0  4.605170   9.210340
# 4          linguist   2.0  2.120264   4.240527
# ...             ...   ...       ...        ...
# 1024  determination   1.0  4.605170   4.605170
# 1025       enhanced   1.0  4.605170   4.605170
# 1026       supposed   1.0  4.605170   4.605170
# 1027       notation   1.0  3.912023   3.912023
# 1028         approa   1.0  2.120264   2.120264
#
# [1029 rows x 4 columns]

# %%
#2.2
#importing required libraries
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from nltk.corpus import stopwords
import numpy as np
import numpy.linalg as LA

# %%
tn_set = df['cln_abstract'].values.tolist() #train set
tt_set = "bwill see realdonaldtrump family getting vaccinated covid model behavior covidvaccine" #Query taken from one of the tweets which is called test set
tt_set = [tt_set]
stopWords = stopwords.words('english')
vzer = CountVectorizer(stop_words = stopWords)
#print(vectorizer)
transformer = TfidfTransformer()
#print(transformer)

# %%
tnVectorizerArray = vzer.fit_transform(tn_set).toarray()
ttVectorizerArray = vzer.transform(tt_set).toarray()
cx = lambda a, b : np.inner(a, b)/(LA.norm(a)*LA.norm(b))
cosine_values = []

# %%
for vector in tnVectorizerArray:
        for testV in ttVectorizerArray:
            cosine = cx(vector, testV)
            cosine_values.append(cosine)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_result = df.filter(['cln_abstract'], axis=1)
se = pd.Series(cosine_values)
df_result['Cosine_similarity'] = se.values
df_result
# Out:
#                                          Abstract_cln  Cosine_similarity
# 0   introduction statistical natural language proc...           0.102062
# 1   the paper summarizes essential property docume...           0.000000
# 2   abstract language way communicating word langu...           0.000000
# 3   we report experiment use standard natural lang...           0.000000
# 4   paper describe simple rule based approach auto...           0.000000
# ..                                                ...                ...
# 95                                       bibliography           0.000000
# 96  applying natural language processing technique...           0.000000
# 97  example natural language chinese english itali...           0.000000
# 98  a number powerful modelling technique develope...           0.123091
# 99  a semi automated approach design database enha...           0.000000
#
# [100 rows x 2 columns]

# %% [markdown]
# # **Question 3: Create your own training and evaluation data for sentiment analysis**

# %% [markdown]
# (15 points). **You dodn't need to write program for this question!** Read each review (abstract or tweet) you collected in detail, and annotate each review with a sentiment (positive, negative, or neutral). Save the annotated dataset into a csv file with three columns (first column: document_id, clean_text, sentiment), upload the csv file to GitHub and submit the file link blew. This datset will be used for assignment four: sentiment analysis and text classification.

# %%
# The GitHub link of your final csv file

# Link: https://github.com/muraliRoyal1/venkatasiva_INFO5731_Fall2020/blob/master/Murali_Assignment_Three.ipynb
